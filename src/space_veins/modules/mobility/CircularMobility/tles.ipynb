# %%
import sys
sys.path.append('/workspaces/ma-max-wendler/scripts/keplertraces')
from math import inf

# %%
from tleparse import read

# %%
tles = read("/workspaces/ma-max-wendler/examples/space_veins/tles/iridiumNEXT_2023-10-22-21-39-19.txt")
print(tles)
min_ecc_tle = None
min_ecc = inf
for tle in tles:
    if tle.ecc < min_ecc:
        min_ecc = tle.ecc
        min_ecc_tle = tle
min_ecc_tle
# Out:
# [TLE(name='IRIDIUM 106', norad='41917', classification='U', int_desig='17003A', epoch_year=2023, epoch_day=295.91774854, dn_o2=1.91e-06, ddn_o6=0.0, bstar=6.0989e-05, set_num=999, inc=86.3949, raan=133.2138, ecc=0.0001982, argp=93.4819, M=266.6603, n=14.34216513, rev_num=35442), TLE(name='IRIDIUM 103', norad='41918', classification='U', int_desig='17003B', epoch_year=2023, epoch_day=295.83530319, dn_o2=1.71e-06, ddn_o6=0.0, bstar=5.4057e-05, set_num=999, inc=86.3946, raan=133.1508, ecc=0.0001853, argp=82.2229, M=277.9177, n=14.34215425, rev_num=35443), TLE(name='IRIDIUM 109', norad='41919', classification='U', int_desig='17003C', epoch_year=2023, epoch_day=295.91142041, dn_o2=1.47e-06, ddn_o6=0.0, bstar=4.5342e-05, set_num=999, inc=86.395, raan=133.1626, ecc=0.0002235, argp=82.4778, M=277.6672, n=14.3421521, rev_num=35441), TLE(name='IRIDIUM 102', norad='41920', classification='U', int_desig='17003D', epoch_year=2023, epoch_day=296.08899105, dn_o2=1.29e-06, ddn_o6=0.0, bstar=3.9043e-
# ...
